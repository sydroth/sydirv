# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - Box Office Mojo: bo_mojo
# - Rotten Tomatoes: rt_movies, rt_reviews
# - TheMovieDB.org: tmdb_movies
# - the-numbers.com: tn_budgets

# %%
bo_mojo = pd.read_csv('unzippedData/bom.movie_gross.csv')
bo_mojo.info()
bo_mojo.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
theMovieDB = pd.read_csv('unzippedData/tmdb.movies.csv')
theMovieDB.info()
theMovieDB[theMovieDB['original_title']=='Toy Story']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
# Unnamed: 0           26517 non-null int64
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB
#       Unnamed: 0        genre_ids   id original_language original_title  \
# 3              3  [16, 35, 10751]  862                en      Toy Story
# 2473        2473  [16, 35, 10751]  862                en      Toy Story
#
#       popularity release_date      title  vote_average  vote_count
# 3         28.005   1995-11-22  Toy Story           7.9       10174
# 2473      28.005   1995-11-22  Toy Story           7.9       10174

# %%
the_numbers = pd.read_csv('unzippedData/tn.movie_budgets.csv')
the_numbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
rt_reviews = pd.read_csv('unzippedData/rt.reviews.tsv', sep='\t', index_col=False, encoding = 'unicode_escape')
rt_reviews.head()
rt_reviews['id'].value_counts()
# Out:
# 782     338
# 1067    275
# 1525    262
# 1777    260
# 1083    260
#        ...
# 28        1
# 102       1
# 348       1
# 476       1
# 1727      1
# Name: id, Length: 1135, dtype: int64

# %%
rt_movies= pd.read_csv('unzippedData/rt.movie_info.tsv', sep='\t', index_col=False, encoding = 'unicode_escape')
rt_movies.info()
# rt_movies[rt_movies['id']==3]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
# id              1560 non-null int64
# synopsis        1498 non-null object
# rating          1557 non-null object
# genre           1552 non-null object
# director        1361 non-null object
# writer          1111 non-null object
# theater_date    1201 non-null object
# dvd_date        1201 non-null object
# currency        340 non-null object
# box_office      340 non-null object
# runtime         1530 non-null object
# studio          494 non-null object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
rt_reviews = pd.read_csv('unzippedData/rt.reviews.tsv', sep='\t', index_col=False, encoding = 'unicode_escape')
rt_reviews.info()
#rt_reviews[rt_reviews['id']==3 & rt_reviews['fresh']=='fresh']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
# id            54432 non-null int64
# review        48869 non-null object
# rating        40915 non-null object
# fresh         54432 non-null object
# critic        51710 non-null object
# top_critic    54432 non-null int64
# publisher     54123 non-null object
# date          54432 non-null object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
#reddit_data=pd.read_csv('reddit_rt_data.csv', sep='\t', encoding = 'unicode_escape')
reddit_data=pd.read_excel('reddit_rt_data2.xlsx')
reddit_data.head()
# Out:
#    Audience Score  audience-critic  REFER  Critics Score  Number of Records  \
# 0              88               36     88             52                  1
# 1              95                5     95             90                  1
# 2              95                5     95             90                  1
# 3              94               -3     94             97                  1
# 4              94               -3     94             97                  1
#
#    Overall Weekend     Top 12                  Top Movie  Total Movies  \
# 0        263441658  256234635              The Lion King            97
# 1        126927836  117914304  Spider-Man: Far from Home           100
# 2        183814995  177831910  Spider-Man: Far from Home            94
# 3        151836451  142785627                Toy Story 4            94
# 4        203828132  195969810                Toy Story 4           100
#
#    Week/Year  Week     Weekend  Year
# 0  2019 - 29    29  Jul. 19–21  2019
# 1  2019 - 28    28  Jul. 12–14  2019
# 2  2019 - 27    27    Jul. 5–7  2019
# 3  2019 - 26    26  Jun. 28–30  2019
# 4  2019 - 25    25  Jun. 21–23  2019

# %%
reddit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 13 columns):
# Audience Score       263 non-null int64
# audience-critic      263 non-null int64
# REFER                263 non-null int64
# Critics Score        263 non-null int64
# Number of Records    263 non-null int64
# Overall Weekend      263 non-null int64
# Top 12               263 non-null int64
# Top Movie            263 non-null object
# Total Movies         263 non-null int64
# Week/Year            263 non-null object
# Week                 263 non-null int64
# Weekend              263 non-null object
# Year                 263 non-null int64
# dtypes: int64(10), object(3)
# memory usage: 26.8+ KB

# %%
the_numbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
y=the_numbers['release_date'][0]
print(y)
pd.to_datetime(y)
# Out:
# Dec 18, 2009
# Timestamp('2009-12-18 00:00:00')

# %%
the_numbers['release_date']=pd.to_datetime(the_numbers['release_date'])
the_numbers['production_budget'] = the_numbers['production_budget'].str.replace(',', '').str.replace('$', '').astype(int)
the_numbers['domestic_gross'] = the_numbers['domestic_gross'].str.replace(',', '').str.replace('$', '').astype(int)
the_numbers['worldwide_gross'] = the_numbers['worldwide_gross'].str.replace(',', '').str.replace('$', '').astype(int)

# %%
the_numbers['worldwide_gross'][0]
# Out:
# 2776345279

# %%
x1=the_numbers['production_budget']
y1=the_numbers['worldwide_gross']
plt.figure(figsize=(15,10))
ax1 = sns.scatterplot(x=x1, y=y1)
plt.title('Scatterplot of Profitability')
plt.xlabel('Budget')
plt.ylabel('Worldwide Earnings')
plt.show()

# %%
x1=the_numbers['production_budget']
y1=the_numbers['domestic_gross']
plt.figure(figsize=(15,10))
ax1 = sns.scatterplot(x=x1, y=y1)
plt.title('Scatterplot of Profitability')
plt.xlabel('Budget')
plt.ylabel('Domestic Earnings')
plt.show()

# %%
the_numbers['Worldwide Profitability'] = the_numbers['worldwide_gross']/the_numbers['production_budget']

# %%
the_numbers.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  Worldwide Profitability
# 0          425000000       760507625       2776345279                 6.532577
# 1          410600000       241063875       1045663875                 2.546673
# 2          350000000        42762350        149762350                 0.427892
# 3          330600000       459005868       1403013963                 4.243841
# 4          317000000       620181382       1316721747                 4.153696

# %%
the_numbers['Domestic Profitability'] = the_numbers['domestic_gross']/the_numbers['production_budget']
the_numbers.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  \
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747
#
#    Worldwide Profitability  Domestic Profitability
# 0                 6.532577                1.789430
# 1                 2.546673                0.587101
# 2                 0.427892                0.122178
# 3                 4.243841                1.388403
# 4                 4.153696                1.956408

# %%
plt.figure(figsize=(15,10))
ax1 = sns.scatterplot(the_numbers['Domestic Profitability'], the_numbers['Worldwide Profitability'])
plt.title('Worldwide vs Domestic')
plt.xlabel('Domestic Profitability')
plt.ylabel('Worldwide Profitability')
plt.show()

# %%
the_numbers[the_numbers['Domestic Profitability']>180].sort_values(by='Domestic Profitability', ascending=False)
# Out:
#       id release_date                        movie  production_budget  \
# 5745  46   1972-06-30                  Deep Throat              25000
# 5773  74   1993-02-26                  El Mariachi               7000
# 5492  93   2009-09-25          Paranormal Activity             450000
# 5406   7   1999-07-14      The Blair Witch Project             600000
# 5679  80   2015-07-10                  The Gallows             100000
# 5715  16   1995-08-09        The Brothers McMullen              50000
# 5665  66   1974-10-18  The Texas Chainsaw Massacre             140000
#
#       domestic_gross  worldwide_gross  Worldwide Profitability  \
# 5745        45000000         45000000              1800.000000
# 5773         2040920          2041928               291.704000
# 5492       107918810        194183034               431.517853
# 5406       140539099        248300000               413.833333
# 5679        22764410         41656474               416.564740
# 5715        10426506         10426506               208.530120
# 5665        26572439         26572439               189.803136
#
#       Domestic Profitability
# 5745             1800.000000
# 5773              291.560000
# 5492              239.819578
# 5406              234.231832
# 5679              227.644100
# 5715              208.530120
# 5665              189.803136

# %%
#the_numbers[(the_numbers['Worldwide Profitability']>180) & (the_numbers['production_budget']>100000)].sort_values(by='Worldwide Profitability', ascending=False)

# %%
the_numbers['release_year']=the_numbers['release_date'].dt.year

# %%
the_numbers.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  \
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747
#
#    Worldwide Profitability  Domestic Profitability  release_year
# 0                 6.532577                1.789430          2009
# 1                 2.546673                0.587101          2011
# 2                 0.427892                0.122178          2019
# 3                 4.243841                1.388403          2015
# 4                 4.153696                1.956408          2017

# %%
imdb_title_basics=pd.read_csv('unzippedData/imdb.title.basics.csv')
imdb_title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_basics.rename(columns={'primary_title':'movie'}, inplace=True)
imdb_title_basics.head()
# Out:
#       tconst                            movie              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_basics.set_index('movie', inplace=True)
the_numbers.set_index('movie', inplace=True)

# %%
joined_df = the_numbers.join(imdb_title_basics, how='inner')

# %%
joined_df.head(60)
# Out:
#                            id release_date  production_budget  domestic_gross  \
# movie
# #Horror                    16   2015-11-20            1500000               0
# 10 Cloverfield Lane        54   2016-03-11            5000000        72082999
# 10 Days in a Madhouse      48   2015-11-11           12000000           14616
# 12 Rounds                  37   2009-03-27           20000000        12234694
# 12 Strong                  64   2018-01-19           35000000        45819713
# 12 Years a Slave           18   2013-10-18           20000000        56671993
# 127 Hours                   6   2010-11-05           18000000        18335230
# 13 Sins                    51   2014-04-18            4000000            9134
# 1982                       23   2016-03-01            1000000               0
# 1982                       23   2016-03-01            1000000               0
# 2 Guns                     39   2013-08-02           61000000        75612460
# 21                         39   2008-03-28           35000000        81159365
# 21 Jump Street             44   2012-03-16           42000000       138447667
# 22 Jump Street             85   2014-06-13           50000000       191719337
# 23 Blast                   64   2014-10-24            1000000          549185
# 3                          85   2011-09-16            7200000           59774
# 3                          85   2011-09-16            7200000           59774
# 3                          85   2011-09-16            7200000           59774
# 3                          85   2011-09-16            7200000           59774
# 3                          85   2011-09-16            7200000           59774
# 3                          85   2011-09-16            7200000           59774
# 3 Backyards                51   2011-03-11             300000           39475
# 3 Days to Kill             64   2014-02-21           28000000        30697999
# 30 Minutes or Less         60   2011-08-12           28000000        37053924
# 300: Rise of an Empire     26   2014-03-07          110000000       106580051
# 31                         85   2016-10-21            1500000          779820
# 40 Weeks                   45   2014-12-31             900000               0
# 42                         22   2013-04-12           31000000        95020213
# 47 Ronin                   12   2013-12-25          175000000        38362475
# 5 Days of War              47   2011-08-19           12000000           17479
# 50 to 1                    93   2014-03-21           10000000         1069454
# 50/50                      73   2011-09-30            8000000        35016118
# 50/50                      73   2011-09-30            8000000        35016118
# 8 Days                     48   2015-10-13            2500000               0
# 8: The Mormon Proposition  38   2010-06-18            2500000          100280
# 9                          33   2009-09-09           30000000        31749894
# 90 Minutes in Heaven       38   2015-09-11            5000000         4816142
# A Bad Moms Christmas       40   2017-11-01           28000000        72110659
# A Better Life              84   2011-06-24           10000000         1759252
# A Better Life              84   2011-06-24           10000000         1759252
# A Dangerous Method         69   2011-11-23           20000000         5702083
# A Few Best Men             55   2015-05-05           15000000               0
# A Fine Step                18   2014-06-24            1000000               0
# A Ghost Story              86   2017-07-07             100000         1594798
# A Good Day to Die Hard     34   2013-02-14           92000000        67349198
# A Haunted House            12   2013-01-11            2500000        40041683
# A Haunted House 2          89   2014-04-18            4000000        17329487
# A Hologram for the King    47   2016-04-22           35000000         4212494
# A Little Bit of Heaven     39   2012-05-04           12500000           10011
# A Lonely Place to Die      56   2012-03-20            4000000               0
# A Man for All Seasons      69   1966-12-12            3900000        28350000
# A Monster Calls            41   2017-01-06           43000000         3740823
# A Most Violent Year        68   2014-12-31           20000000         5749134
# A Most Wanted Man          76   2014-07-25           15000000        17237855
# A Nightmare on Elm Street  49   2010-04-30           35000000        63075011
# A Nightmare on Elm Street  17   1984-11-09            1800000        25504513
# A Plague So Pleasant       81   2015-09-29               1400               0
# A Quiet Place              66   2018-04-06           17000000       188024361
# A Quiet Place              66   2018-04-06           17000000       188024361
# A Simple Favor             24   2018-09-14           20000000        53548586
#
#                            worldwide_gross  Worldwide Profitability  \
# movie
# #Horror                                  0                 0.000000
# 10 Cloverfield Lane              108286422                21.657284
# 10 Days in a Madhouse                14616                 0.001218
# 12 Rounds                         17306648                 0.865332
# 12 Strong                         71118378                 2.031954
# 12 Years a Slave                 181025343                 9.051267
# 127 Hours                         60217171                 3.345398
# 13 Sins                              47552                 0.011888
# 1982                                     0                 0.000000
# 1982                                     0                 0.000000
# 2 Guns                           132493015                 2.172017
# 21                               159846429                 4.567041
# 21 Jump Street                   202812429                 4.828867
# 22 Jump Street                   331333876                 6.626678
# 23 Blast                            549185                 0.549185
# 3                                   295492                 0.041041
# 3                                   295492                 0.041041
# 3                                   295492                 0.041041
# 3                                   295492                 0.041041
# 3                                   295492                 0.041041
# 3                                   295492                 0.041041
# 3 Backyards                          39475                 0.131583
# 3 Days to Kill                    38959900                 1.391425
# 30 Minutes or Less                40966716                 1.463097
# 300: Rise of an Empire           330780051                 3.007091
# 31                                  922727                 0.615151
# 40 Weeks                                 0                 0.000000
# 42                                97470701                 3.144216
# 47 Ronin                         151716815                 0.866953
# 5 Days of War                        87793                 0.007316
# 50 to 1                            1069454                 0.106945
# 50/50                             41334735                 5.166842
# 50/50                             41334735                 5.166842
# 8 Days                                   0                 0.000000
# 8: The Mormon Proposition           100280                 0.040112
# 9                                 48559999                 1.618667
# 90 Minutes in Heaven               4816142                 0.963228
# A Bad Moms Christmas             127710550                 4.561091
# A Better Life                      1884251                 0.188425
# A Better Life                      1884251                 0.188425
# A Dangerous Method                14807531                 0.740377
# A Few Best Men                    17224539                 1.148303
# A Fine Step                              0                 0.000000
# A Ghost Story                      2769782                27.697820
# A Good Day to Die Hard           304249198                 3.307056
# A Haunted House                   59922558                23.969023
# A Haunted House 2                 21206861                 5.301715
# A Hologram for the King           11846010                 0.338457
# A Simple Favor                        A Simple Favor        2018
#
#                            runtime_minutes                        genres
# movie
# #Horror                              101.0            Crime,Drama,Horror
# 10 Cloverfield Lane                  103.0          Drama,Horror,Mystery
# 10 Days in a Madhouse                111.0                         Drama
# 12 Rounds                              NaN          Action,Drama,Romance
# 12 Strong                            130.0          Action,Drama,History
# 12 Years a Slave                     134.0       Biography,Drama,History
# 127 Hours                             94.0     Adventure,Biography,Drama
# 13 Sins                               93.0               Horror,Thriller
# 1982                                  90.0                         Drama
# 1982                                  11.0                   Documentary
# 2 Guns                               109.0           Action,Comedy,Crime
# 21                                    98.0                        Horror
# 21 Jump Street                       109.0           Action,Comedy,Crime
# 22 Jump Street                       112.0           Action,Comedy,Crime
# 23 Blast                              98.0            Drama,Family,Sport
# 3                                    119.0          Comedy,Drama,Romance
# 3                                    145.0         Drama,Mystery,Romance
# 3                                    115.0                  Comedy,Drama
# 3                                     80.0       Horror,Mystery,Thriller
# 3                                     57.0                         Drama
# 3                                     17.0                   Documentary
# 3 Backyards                           88.0                         Drama
# 3 Days to Kill                       117.0         Action,Drama,Thriller
# 30 Minutes or Less                    83.0           Action,Comedy,Crime
# 300: Rise of an Empire               102.0            Action,Fantasy,War
# 31                                   102.0               Horror,Thriller
# 40 Weeks                             111.0                   Documentary
# 42                                   128.0         Biography,Drama,Sport
# 47 Ronin                             128.0        Action,Adventure,Drama
# 5 Days of War                        113.0              Action,Drama,War
# 50 to 1                              110.0                         Drama
# 50/50                                100.0          Comedy,Drama,Romance
# 50/50                                 77.0                   Documentary
# 8 Days                                90.0                Drama,Thriller
# 8: The Mormon Proposition             80.0                   Documentary
# 9                                      NaN                        Comedy
# 90 Minutes in Heaven                 121.0                         Drama
# A Bad Moms Christmas                 104.0              Adventure,Comedy
# A Better Life                         98.0                 Drama,Romance
# A Better Life                        110.0                         Drama
# A Dangerous Method                    99.0       Biography,Drama,Romance
# A Few Best Men                        97.0                Comedy,Romance
# A Fine Step                          111.0                         Drama
# A Ghost Story                         92.0         Drama,Fantasy,Romance
# A Good Day to Die Hard                98.0               Action,Thriller
# A Haunted House                       86.0                Comedy,Fantasy
# A Haunted House 2                     86.0                Comedy,Fantasy
# A Hologram for the King               98.0          Comedy,Drama,Romance
# A Little Bit of Heaven               106.0          Comedy,Drama,Fantasy
# A Lonely Place to Die                 99.0      Adventure,Crime,Thriller
# A Man for All Seasons                 43.0  Biography,Documentary,Family
# A Monster Calls                      108.0       Animation,Drama,Fantasy
# A Most Violent Year                  125.0          Crime,Drama,Thriller
# A Most Wanted Man                    122.0          Crime,Drama,Thriller
# A Nightmare on Elm Street             95.0            Crime,Drama,Horror
# A Nightmare on Elm Street             95.0            Crime,Drama,Horror
# A Plague So Pleasant                  76.0         Drama,Horror,Thriller
# A Quiet Place                         80.0                   Documentary
# A Quiet Place                         90.0           Drama,Horror,Sci-Fi
# A Simple Favor                       117.0            Comedy,Crime,Drama
